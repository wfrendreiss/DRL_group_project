# %% [markdown]
# # DRL Group Project - Setup and Execution
#
# This notebook sets up the environment and runs the main script.

# %% [markdown]
# ## Step 1: Run setup.sh
#
# This will create the conda environment and install all dependencies.

# %%
# !bash setup.sh

# %% [markdown]
# ## Step 2: Select the Kernel
#
# **IMPORTANT**: Before running the next cell, please select the `gymenv` kernel:
# - Click on the kernel name in the top right corner of the notebook
# - Select `gymenv` from the list of available kernels
# - Wait for the kernel to be selected and ready
#
# ### ⚠️ Important Note About Import Error
#
# **If you try to run main.py right now, you will encounter an error** saying that `baselines` is not installed.
#
# **To fix this:**
# 1. The error will occur in the dopamine library file. Look for the file: `dopamine/discrete_domains/atari_lib.py` (it should be in your conda environment's site-packages, e.g., `~/miniconda3/envs/gymenv/lib/python3.12/site-packages/dopamine/discrete_domains/atari_lib.py`)
# 2. Find line 45 which contains: `from baselines.common import atari_wrappers`
# 3. Change it to: `from stable_baselines3.common import atari_wrappers`
# 4. Save the file and then you can run main.py successfully
#
# ## Step 3: Run main.py
#
# After selecting the `gymenv` kernel and fixing the import statement, you can run main.py directly:

# %%
# Now that you've selected the gymenv kernel, you can run main.py directly
exec(open('main.py').read())
